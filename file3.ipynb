# %%
import pandas as p

# %%
import io
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ceb75ce2-2a3f-4dc0-b95c-f5bfa40729a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ceb75ce2-2a3f-4dc0-b95c-f5bfa40729a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datafiles=p.read_csv("data.csv")

# %%
datafiles
# Out:
#         Name        Roll       address branch  Rank
# 0    Haritha  19am1a0510  Chagalamarri    CSE   1.0
# 1    Naveen   19am1a0511       kurnool    CSE   2.0
# 2     Pranay  19am1a0512       nandyal    CSE   3.0
# 3     yogesh  19am1a0513     allagadda    CSE   4.0
# 4     sivani  19am1a0514           NaN    CSE   5.0
# 5   pavithra  19am1a0515       nandyal    CSE   6.0
# 6      Divya  19am1a0516       nandyal    CSE   NaN
# 7    Chandhu         NaN       nandyal    CSE   8.0
# 8     Mayank  19am1a0518       nandyal    CSE   9.0
# 9      Kiran  19am1a0519       nandyal    CSE  10.0
# 10       NaN  19am1a0520       nandyal    CSE  11.0
# 11      Yash  19am1a0521       nandyal    CSE  12.0
# 12   Kishore  19am1a0522       nandyal    NaN  13.0
# 13     Malli  19am1a0523       nandyal    CSE  14.0
# 14    Malini  19am1a0524       nandyal    CSE  15.0
# 15    Sathya  19am1a0525       nandyal    CSE  16.0
# 16      devi  19am1a0526       nandyal    CSE  17.0
# ...

# %%
datafiles.fillna(0)
# Out:
#         Name        Roll       address branch  Rank
# 0    Haritha  19am1a0510  Chagalamarri    CSE   1.0
# 1    Naveen   19am1a0511       kurnool    CSE   2.0
# 2     Pranay  19am1a0512       nandyal    CSE   3.0
# 3     yogesh  19am1a0513     allagadda    CSE   4.0
# 4     sivani  19am1a0514             0    CSE   5.0
# 5   pavithra  19am1a0515       nandyal    CSE   6.0
# 6      Divya  19am1a0516       nandyal    CSE   0.0
# 7    Chandhu           0       nandyal    CSE   8.0
# 8     Mayank  19am1a0518       nandyal    CSE   9.0
# 9      Kiran  19am1a0519       nandyal    CSE  10.0
# 10         0  19am1a0520       nandyal    CSE  11.0
# 11      Yash  19am1a0521       nandyal    CSE  12.0
# 12   Kishore  19am1a0522       nandyal      0  13.0
# 13     Malli  19am1a0523       nandyal    CSE  14.0
# 14    Malini  19am1a0524       nandyal    CSE  15.0
# 15    Sathya  19am1a0525       nandyal    CSE  16.0
# 16      devi  19am1a0526       nandyal    CSE  17.0
# ...

# %%
datafiles.plot()

# %%
datafiles.info
# Out:
# <bound method DataFrame.info of         Name        Roll       address branch  Rank
# 0    Haritha  19am1a0510  Chagalamarri    CSE   1.0
# 1    Naveen   19am1a0511       kurnool    CSE   2.0
# 2     Pranay  19am1a0512       nandyal    CSE   3.0
# 3     yogesh  19am1a0513     allagadda    CSE   4.0
# 4     sivani  19am1a0514           NaN    CSE   5.0
# 5   pavithra  19am1a0515       nandyal    CSE   6.0
# 6      Divya  19am1a0516       nandyal    CSE   NaN
# 7    Chandhu         NaN       nandyal    CSE   8.0
# 8     Mayank  19am1a0518       nandyal    CSE   9.0
# 9      Kiran  19am1a0519       nandyal    CSE  10.0
# 10       NaN  19am1a0520       nandyal    CSE  11.0
# 11      Yash  19am1a0521       nandyal    CSE  12.0
# 12   Kishore  19am1a0522       nandyal    NaN  13.0
# 13     Malli  19am1a0523       nandyal    CSE  14.0
# 14    Malini  19am1a0524       nandyal    CSE  15.0
# 15    Sathya  19am1a0525       nandyal    CSE  16.0
# ...

# %%
type(datafiles.Rank)
# Out:
# pandas.core.series.Series

# %%
datafiles["Rank"].mean()
# Out:
# 10.166666666666666

# %%
datafiles["Rank"]
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      NaN
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# Name: Rank, dtype: float64
